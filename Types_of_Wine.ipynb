# %%
# Libraries for data handling and analysis
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Scikit-learn utilities and models
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report

# %%
# Importing the data to a Dataframe
data_all = pd.read_csv('WineQuality.csv')

# %%
data_all.head()
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        2732            7.4             0.170         0.29             1.4
# 1        2607            5.3             0.310         0.38            10.5
# 2        1653            4.7             0.145         0.29             1.0
# 3        3264            6.9             0.260         0.29             4.2
# 4        4931            6.4             0.450         0.07             1.1
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.047                 23.0                 107.0  0.99390  3.52
# 1      0.031                 53.0                 140.0  0.99321  3.34
# 2      0.042                 35.0                  90.0  0.99080  3.76
# 3      0.043                 33.0                 114.0  0.99020  3.16
# 4      0.030                 10.0                 131.0  0.99050  2.97
#
#    sulphates  alcohol  quality        Type
# ...

# %%
data_all.shape
# Out:
# (999, 14)

# %%
# After getting the columns, getting some general information of dataset
data_all.describe()
# Out:
#         Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# count   999.000000     999.000000        999.000000   999.000000
# mean   3236.805806       7.220571          0.341406     0.324875
# std    1903.776692       1.272520          0.165308     0.154876
# min       0.000000       3.900000          0.080000     0.000000
# 25%    1636.000000       6.500000          0.230000     0.250000
# 50%    3191.000000       7.000000          0.290000     0.310000
# 75%    4963.500000       7.700000          0.400000     0.400000
# max    6496.000000      15.600000          1.330000     1.000000
#
#        residual sugar   chlorides  free sulfur dioxide  total sulfur dioxide  \
# count      999.000000  999.000000           999.000000            999.000000
# mean         5.537087    0.055421            30.369870            116.237237
# std          4.826708    0.030000            17.712044             57.208390
# ...

# %%
# Checking any missing values.
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            999 non-null    int64
#  1   fixed acidity         999 non-null    float64
#  2   volatile acidity      999 non-null    float64
#  3   citric acid           999 non-null    float64
#  4   residual sugar        999 non-null    float64
#  5   chlorides             999 non-null    float64
#  6   free sulfur dioxide   999 non-null    float64
#  7   total sulfur dioxide  999 non-null    float64
#  8   density               999 non-null    float64
#  9   pH                    999 non-null    float64
#  10  sulphates             999 non-null    float64
#  11  alcohol               999 non-null    float64
#  12  quality               999 non-null    int64
#  13  Type                  999 non-null    object
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
data_all.nunique()
# Out:
# Unnamed: 0              928
# fixed acidity            81
# volatile acidity        102
# citric acid              80
# residual sugar          196
# chlorides               113
# free sulfur dioxide      91
# total sulfur dioxide    228
# density                 415
# pH                       84
# sulphates                76
# alcohol                  64
# quality                   7
# Type                      2
# dtype: int64

# %%
# We have two possibilities for the types of wine i.e., red and white.
# First goal is to determine if wine is red or white depending on the variable.

# %%
# By using Random Forest we have to classify the types of wine.

# %%
# Data visualization
data_all.drop('Unnamed: 0', axis=1, inplace=True)

# %%
#we want it depending on the type
column = data_all.columns.drop('Type')

#create plots
plt.figure(figsize = (20,30))
for i,j in enumerate(column):
    ax = plt.subplot(6,2, i+1)
    sns.histplot(x = data_all[j], hue = data_all['Type'])
plt.tight_layout()
# Out:
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\ayush\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
Model

# %%
#separate test and train
x_train, x_test, y_train, y_test = train_test_split(data_all.drop('Type', axis=1), data_all.Type)

# %%
#scale the data
scaler = StandardScaler()
x_train  = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %%
#start random forest
model = RandomForestClassifier()
model.fit(x_train, y_train)
test_pred = model.predict(x_test)
train_pred = model.predict(x_train)

# %%
print('Train data report : ')
print(classification_report(y_train, train_pred))

print('Test data report : ')
print(classification_report(y_test, test_pred))
# Out:
# Train data report :
#               precision    recall  f1-score   support
#
#     Red Wine       1.00      1.00      1.00       189
#   White Wine       1.00      1.00      1.00       560
#
#     accuracy                           1.00       749
#    macro avg       1.00      1.00      1.00       749
# weighted avg       1.00      1.00      1.00       749
#
# Test data report :
#               precision    recall  f1-score   support
#
#     Red Wine       0.96      0.98      0.97        47
#   White Wine       1.00      0.99      0.99       203
#
#     accuracy                           0.99       250
#    macro avg       0.98      0.98      0.98       250
# weighted avg       0.99      0.99      0.99       250

# %%
confusion_matrix(y_test, test_pred)
# Out:
# array([[ 46,   1],
#        [  2, 201]], dtype=int64)
